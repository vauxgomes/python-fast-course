# %% [markdown]
# # Exercices (Portuguese)
#
# ### Listas
# 1. `questao_1.py`: `[2:00]` Escreva um programa que pede o nome, o sobrenome e a idade do usuário, salva em uma lista e imprime a lista no final.
#
# ```
# Digite seu nome: John
# Digite seu sobrenome: Snow
# Digite sua idade: 25
#
# Lista: ['John', 'Snow', 25]
# ```
#
# 2. `questao_2.py`: `[6:00]` Utilizando listas faça um programa que faça 5 perguntas para uma pessoa sobre um crime. As perguntas são:
#  - Telefonou para a vítima (S/n)?
#  - Esteve no local do crime (S/n)?
#  - Mora perto da vítima (S/n)?
#  - Devia para a vítima (S/n)?
#  - Já trabalhou com a vítima (S/n)?
#
# O programa deve, no final, emitir uma classificação sobre a participação da pessoa no crime. Se a pessoa responder positivamente a 2 questões ela deve ser classificada como "Suspeita", entre 3 e 4 como "Cúmplice" e 5 como "Assassino". Caso contrário, ele será classificado como "Inocente".
#
# ### Loop `for`
# 3. `questao_3.py`: `[4:00]` Escreva um programa que leia um vetor com 10 números inteiros, calcule e mostre a soma dos quadrados dos elementos do vetor.
#
# | Exemplo               | Saída |
# |-----------------------|-------|
# |[4,3,2,0,2,4,6,5,5,2]  | 139   |
# |[5,5,2,8,7,10,10,5,5,9]| 498   |
#
# 4. `questao_4.py`: `[2:00]` Escreva um programa que imprime o vetor `[4,3,2,0,2,4,6,5,5,2]` na ordem inversa.
#
#
# 5. `questao_5.py`: `[6:00]` Escreva um programa pede as notas N1 e N2 de 3 alunos e posteriormente imprime a suas médias.
#
# ```
# Aluno 1
# Digite N1: 7.0
# Digite N2: 8.5
#
# Aluno 2
# Digite N1: 4.0
# Digite N2: 7.0
#
# Aluno 3
# Digite N1: 8.0
# Digite N2: 3.5
#
# Médias
# ---------------------
# Aluno 1: 7.75
# Aluno 2: 5.5
# Aluno 3: 5.75
# ```
#
# 6. `questao_6.py`: `[4:00]` Escreva um programa que peça a idade e a altura (cm) de `5 pessoas`, armazene cada informação em uma matriz. Imprima a matriz no final.
#
# ```
# Pessoa 1
# Digite Idade: 25
# Digite Altura (cm): 169
#
# ...
#
# Pessoa 5
# Digite Idade: 12
# Digite Altura: 130
#
# Matriz: [[25, 169], ..., [12, 130]]
# ```
#
# 7. `questão_7.py`: `[3:00]` Escreva um programa que recebe 2 valores do usuário e informa se os números entre os intervalos dos valores estão no vetor `[5,5,2,8,7,10,10,5,5,9]`.
#
# ```
# Menor valor: 3
# Maior valor: 12
#
# O valor 3 não está no vetor
# O valor 4 não está no vetor
# O valor 5 está no vetor
# O valor 6 não está no vetor
# O valor 7 está no vetor
# O valor 8 está no vetor
# O valor 9 está no vetor
# O valor 10 está no vetor
# O valor 11 não está no vetor
# O valor 12 não está no vetor
# ```
#
# 8. `questao_8.py`: `[8:00]` Escreva um programa que pergunta ao usuário a quantidade de números que ele quer salvar, pergunta por cada valor e imprime a média e a soma dos valores.
#
# ```
# Quantos valores você quer salvar: 4
# Valor 1: 7.56
# Valor 2: 3.14
# Valor 3: -8.95
# Valor 4: 0.03
# --------------------------
# Soma: 1.78
# Média: 0.445
# ```
#
# 9. `questao_9.py`: `[9:00]` Escolha um valor entre 1 e 20 para ser um valor secreto. Escreva um programa que pergunta ao usuário 3 vezes pelo valor secreto. Caso ele acerte o programa deve exibir uma mensagem de acerto e parar de perguntar. (Exemplo: valor_secreto = 12)
#
# ```
# O valor secreto é um número entre 1 e 20
# Tentativa 1: 5
#  [!]: Errou!
#  [!]: O valor secreto é maior que 5.
#  [!]: Você tem mais 2 tentativa(s).
#
# Tentativa 2: 12
#  [!]: Acertou, mizeravi!
#
# FIM DE JOGO: VOCÊ ACERTOU NA TENTATIVA 2
# ```
# ----
# ```
# O valor secreto é um número entre 1 e 20
# Tentativa 1: 5
#  [!]: Errou!
#  [!]: O valor secreto é maior que 5.
#  [!]: Você tem mais 2 tentativa(s).
#
# Tentativa 2: 18
#  [!]: Errou!
#  [!]: O valor secreto é menor que 18.
#  [!]: Você tem mais 1 tentativa(s).
#
# Tentativa 3: 11
#  [!]: Errou!
#  [!]: O valor secreto é maior que 11.
#  [!]: Você não tem mais tentativas.
#
# FIM DE JOGO: VOCÊ NÃO ACERTOU O VALOR SECRETO
# ```
#
# 10. `questao_10.py`: `[10:00]` Escreva um programa que lê uma pergunta, suas alternativas e a resposta correta, faz a pergunta ao usuário e verifica se acertou ou não.
#
# ```
# Digite a pergunta: Qual o melhor Sistema Operacional para uso em servidores?
# Quantidade de alternativas: 6
# Alternativa 1: Windows Server
# Alternativa 2: Unix
# Alternativa 3: Linux
# Alternativa 4: Netware
# Alternativa 5: Mac OS
# Alternativa 6: Outro
# Qual é a resposta correta: 3
# ---------------------------------------
# PERGUNTA: Qual o melhor Sistema Operacional para uso em servidores?
# ALTERNATIVA:
# 1- Windows Server
# 2- Unix
# 3- Linux
# 4- Netware
# 5- Mac OS
# 6- Outro
# RESPONDA: 5
# ---------------------------------------
# Você errou! A resposta correta é: Linux
# ```
#
# 11. `questao_11.py`: `[3:00]` Escreva um programa que imprime uma matriz com valores de até 4 dígitos.
# ```py
# matriz = [[1087, 701, 361, 34, 762], [8, 1172, 255, 1111, 880], [469, 897, 182, 797, 807], [1105, 235, 1194, 314, 718]]
# ```
#
# ```
# MATRIZ
# 1087  701  361   34  762
#    8 1172  255 1111  880
#  469  897  182  797  807
# 1105  235 1194  314  718
# ```
#
# Dica: Utilize o `rjust`
