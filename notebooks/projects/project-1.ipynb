# %% [markdown]
# # Projeto 1
#
# Utilize conhecimentos adquiridos até aqui para criar um pequeno sistema para gravar contatos em um vetor.
# Cada posição do vetor deve conter um dicionário no formato a seguir:
#
# ```py
# person = {
#     'nome': '',
#     'sobrenome': '',
#     'numero': '',
#     'email': ''
# }
# ```
#
# Implemente funções para criar uma pessoa (`person`) no formato acima. Adicione condições para que uma pessoa sempre possua um nome, e um número ou um email.
#
# Implemente uma função que imprima cada cotato da lista como segue os exemplos:
#
# ```
# Johnson, Bob
# Contacts:
#  > 555-2368
#  > bob.johnson@example.com
#
# Alice
# Contact:
#  > alice.madwoman@example.com
# ```
# Onde o primeiro exemplo contém todos os dados e o segundo contém apenas o nome e o email.
#
# Segue o código base:

# %%
# Variáveis
contacts = []

def create_contact():
    ''' Esta função gera um contato com nome e um número de contato ou email '''
    return None

def add_contact(contacts, contact):
    ''' Esta função adiciona um contato ao fim do array de contatos '''
    pass

def remove_contact(contacts, name):
    ''' Esta função remove um contato utilizando o nome como pesquisa '''
    pass

def print_contacts(contacts):
    ''' Esta função imprime os contatos gera um contato com nome e um número de contato ou email '''
    pass

def save_contacts(contacts, file = 'resources/tmp.txt'):
    ''' Esta função salva os contatos em um arquivo. Utilize qualquer formato '''
    pass

# Main
if __name__ == '__main__':
    while True:
        print('Menu'.upper().center(10))
        print('-'*10)
        print('Add:'.ljust(8),1)
        print('Remove:'.ljust(8),2)
        print('Print:'.ljust(8),3)
        print('Save:'.ljust(8),4)
        print('Exit:'.ljust(8),9)
        print('-'*10)
            
        # Option
        opt = 0
        while opt not in [1,2,3,4,9]:
            opt = int(input('Option:'.ljust(9)))
            
        # Using option
        if opt == 9:
            break
            
        elif opt == 1:
            print('Add'.upper().center(10))
            contact = create_contact()
            add_contact(contacts, contact)
            
        elif opt == 2:
            print('Remove'.upper().center(10))
            name = None # TODO
            remove_contact(contacts, name)
            
        elif opt == 3:
            print('Print'.upper().center(10))
            print_contacts(contacts)
            
        elif opt == 4:
            print('Save'.upper().center(10))
            save_contacts(contacts)
            
    print('Program ended'.upper())
